# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
type(nyt_api_key)
# Out:
# str

# %% [markdown]
# ### Access the New York Times API

# %%
# # Set the base URL
# url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# # Filter for movie reviews with "love" in the headline
# # section_name should be "Movies"
# # type_of_material should be "Review"
# # filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# # Use a sort filter, sort by newest
# # sort = "newest"

# # Select the following fields to return:
# # headline, web_url, snippet, source, keywords, pub_date, byline, word_count
# # field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# # Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# # Build URL

# %%
# New York Times Article API URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Search for articles that mention movie
query = "James Bond"

# Build query URL
query_url = url + "api-key=" + nyt_api_key + "&q=" + query
print(query_url)

# Request articles
articles = requests.get(query_url).json()

# The "response" property in articles contains the actual articles
# list comprehension.
articles_list = articles["response"]["docs"]
print(json.dumps(articles_list, indent=4))
# Out:
# https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=efe3txBx6j9JZB8VClnGGi5LuzujDZT8&q=James Bond
# [
#     {
#         "abstract": "Why wokeness seems so powerful in Britain and Canada.",
#         "web_url": "https://www.nytimes.com/2023/09/06/opinion/columnists/james-bond-woke-uk-progressive.html",
#         "snippet": "Why wokeness seems so powerful in Britain and Canada.",
#         "lead_paragraph": "After so many decades fighting evil masterminds bent on Britannia\u2019s destruction, the 21st-century version of James Bond has found a very 21st-century antagonist. In the newest Bond novel, \u201cOn His Majesty\u2019s Secret Service,\u201d 007 is charged with protecting King Charles III from a dastardly plot hatched by a supervillain whose nom de guerre is Athelstan of Wessex \u2014 in other words, a Little Englander, a Brexiteer, a right-wing populist, apparently the true and natural heir to Goldfinger and Blofeld.",
#         "source": "The New York Times",
#         "multimedia": [
#             {
#                 "rank": 0,
#                 "subtype": "xlarge",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-articleLarge.jpg",
#                 "height": 400,
#                 "width": 600,
#                 "legacy": {
#                     "xlarge": "images/2023/09/06/opinion/06douthat1/06douthat1-articleLarge.jpg",
#                     "xlargewidth": 600,
#                     "xlargeheight": 400
#                 },
#                 "subType": "xlarge",
#                 "crop_name": "articleLarge"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "popup",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-popup.jpg",
#                 "height": 433,
#                 "width": 650,
#                 "legacy": {},
#                 "subType": "popup",
#                 "crop_name": "popup"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blog480",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-blog480.jpg",
#                 "height": 320,
#                 "width": 480,
#                 "legacy": {},
#                 "subType": "blog480",
#                 "crop_name": "blog480"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blog533",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-blog533.jpg",
#                 "height": 355,
#                 "width": 533,
#                 "legacy": {},
#                 "subType": "blog533",
#                 "crop_name": "blog533"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blog427",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-blog427.jpg",
#                 "height": 285,
#                 "width": 427,
#                 "legacy": {},
#                 "subType": "blog427",
#                 "crop_name": "blog427"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "tmagSF",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-tmagSF.jpg",
#                 "height": 241,
#                 "width": 362,
#                 "legacy": {},
#                 "subType": "tmagSF",
#                 "crop_name": "tmagSF"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "tmagArticle",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-tmagArticle.jpg",
#                 "height": 395,
#                 "width": 592,
#                 "legacy": {},
#                 "subType": "tmagArticle",
#                 "crop_name": "tmagArticle"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "slide",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-slide.jpg",
#                 "height": 400,
#                 "width": 600,
#                 "legacy": {},
#                 "subType": "slide",
#                 "crop_name": "slide"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "jumbo",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-jumbo.jpg",
#                 "height": 683,
#                 "width": 1024,
#                 "legacy": {},
#                 "subType": "jumbo",
#                 "crop_name": "jumbo"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "superJumbo",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-superJumbo.jpg",
#                 "height": 1365,
#                 "width": 2048,
#                 "legacy": {},
#                 "subType": "superJumbo",
#                 "crop_name": "superJumbo"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blog225",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-blog225.jpg",
#                 "height": 150,
#                 "width": 225,
#                 "legacy": {},
#                 "subType": "blog225",
#                 "crop_name": "blog225"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master1050",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-master1050.jpg",
#                 "height": 700,
#                 "width": 1050,
#                 "legacy": {},
#                 "subType": "master1050",
#                 "crop_name": "master1050"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master675",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-master675.jpg",
#                 "height": 450,
#                 "width": 675,
#                 "legacy": {},
#                 "subType": "master675",
#                 "crop_name": "master675"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master495",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-master495.jpg",
#                 "height": 330,
#                 "width": 495,
#                 "legacy": {},
#                 "subType": "master495",
#                 "crop_name": "master495"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master180",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-master180.jpg",
#                 "height": 120,
#                 "width": 180,
#                 "legacy": {},
#                 "subType": "master180",
#                 "crop_name": "master180"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master315",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-master315.jpg",
#                 "height": 210,
#                 "width": 315,
#                 "legacy": {},
#                 "subType": "master315",
#                 "crop_name": "master315"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master768",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-master768.jpg",
#                 "height": 512,
#                 "width": 768,
#                 "legacy": {},
#                 "subType": "master768",
#                 "crop_name": "master768"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "thumbnail",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-thumbStandard.jpg",
#                 "height": 75,
#                 "width": 75,
#                 "legacy": {
#                     "thumbnail": "images/2023/09/06/opinion/06douthat1/06douthat1-thumbStandard.jpg",
#                     "thumbnailwidth": 75,
#                     "thumbnailheight": 75
#                 },
#                 "subType": "thumbnail",
#                 "crop_name": "thumbStandard"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blogSmallThumb",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-blogSmallThumb.jpg",
#                 "height": 50,
#                 "width": 50,
#                 "legacy": {},
#                 "subType": "blogSmallThumb",
#                 "crop_name": "blogSmallThumb"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "thumbLarge",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-thumbLarge.jpg",
#                 "height": 150,
#                 "width": 150,
#                 "legacy": {},
#                 "subType": "thumbLarge",
#                 "crop_name": "thumbLarge"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "smallSquare168",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-smallSquare168.jpg",
#                 "height": 168,
#                 "width": 168,
#                 "legacy": {},
#                 "subType": "smallSquare168",
#                 "crop_name": "smallSquare168"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "smallSquare252",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-smallSquare252.jpg",
#                 "height": 252,
#                 "width": 252,
#                 "legacy": {},
#                 "subType": "smallSquare252",
#                 "crop_name": "smallSquare252"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "square320",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-square320.jpg",
#                 "height": 320,
#                 "width": 320,
#                 "legacy": {},
#                 "subType": "square320",
#                 "crop_name": "square320"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "moth",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-moth.jpg",
#                 "height": 151,
#                 "width": 151,
#                 "legacy": {},
#                 "subType": "moth",
#                 "crop_name": "moth"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "filmstrip",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-filmstrip.jpg",
#                 "height": 190,
#                 "width": 190,
#                 "legacy": {},
#                 "subType": "filmstrip",
#                 "crop_name": "filmstrip"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "square640",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-square640.jpg",
#                 "height": 640,
#                 "width": 640,
#                 "legacy": {},
#                 "subType": "square640",
#                 "crop_name": "square640"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mediumSquare149",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-mediumSquare149.jpg",
#                 "height": 149,
#                 "width": 149,
#                 "legacy": {},
#                 "subType": "mediumSquare149",
#                 "crop_name": "mediumSquare149"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mediumSquareAt3X",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-mediumSquareAt3X.jpg",
#                 "height": 1800,
#                 "width": 1800,
#                 "legacy": {},
#                 "subType": "mediumSquareAt3X",
#                 "crop_name": "mediumSquareAt3X"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "sfSpan",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-sfSpan.jpg",
#                 "height": 263,
#                 "width": 395,
#                 "legacy": {},
#                 "subType": "sfSpan",
#                 "crop_name": "sfSpan"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "largeHorizontal375",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-largeHorizontal375.jpg",
#                 "height": 250,
#                 "width": 375,
#                 "legacy": {},
#                 "subType": "largeHorizontal375",
#                 "crop_name": "largeHorizontal375"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "largeHorizontalJumbo",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-largeHorizontalJumbo.jpg",
#                 "height": 683,
#                 "width": 1024,
#                 "legacy": {},
#                 "subType": "largeHorizontalJumbo",
#                 "crop_name": "largeHorizontalJumbo"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "horizontalMediumAt2X",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-horizontalMediumAt2X.jpg",
#                 "height": 3630,
#                 "width": 5445,
#                 "legacy": {},
#                 "subType": "horizontalMediumAt2X",
#                 "crop_name": "horizontalMediumAt2X"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "hpLarge",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-hpLarge.jpg",
#                 "height": 287,
#                 "width": 511,
#                 "legacy": {},
#                 "subType": "hpLarge",
#                 "crop_name": "hpLarge"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "largeWidescreen573",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-largeWidescreen573.jpg",
#                 "height": 322,
#                 "width": 573,
#                 "legacy": {},
#                 "subType": "largeWidescreen573",
#                 "crop_name": "largeWidescreen573"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "largeWidescreen1050",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-largeWidescreen1050.jpg",
#                 "height": 591,
#                 "width": 1050,
#                 "legacy": {},
#                 "subType": "largeWidescreen1050",
#                 "crop_name": "largeWidescreen1050"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "wide",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-thumbWide.jpg",
#                 "height": 126,
#                 "width": 190,
#                 "legacy": {
#                     "widewidth": 190,
#                     "wideheight": 126,
#                     "wide": "images/2023/09/06/opinion/06douthat1/06douthat1-thumbWide.jpg"
#                 },
#                 "subType": "wide",
#                 "crop_name": "thumbWide"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoThumb",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-videoThumb.jpg",
#                 "height": 50,
#                 "width": 75,
#                 "legacy": {},
#                 "subType": "videoThumb",
#                 "crop_name": "videoThumb"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoLarge",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-videoLarge.jpg",
#                 "height": 507,
#                 "width": 768,
#                 "legacy": {},
#                 "subType": "videoLarge",
#                 "crop_name": "videoLarge"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mediumThreeByTwo210",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-mediumThreeByTwo210.jpg",
#                 "height": 140,
#                 "width": 210,
#                 "legacy": {},
#                 "subType": "mediumThreeByTwo210",
#                 "crop_name": "mediumThreeByTwo210"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mediumThreeByTwo225",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-mediumThreeByTwo225.jpg",
#                 "height": 150,
#                 "width": 225,
#                 "legacy": {},
#                 "subType": "mediumThreeByTwo225",
#                 "crop_name": "mediumThreeByTwo225"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mediumThreeByTwo440",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-mediumThreeByTwo440.jpg",
#                 "height": 293,
#                 "width": 440,
#                 "legacy": {},
#                 "subType": "mediumThreeByTwo440",
#                 "crop_name": "mediumThreeByTwo440"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mediumThreeByTwo252",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-mediumThreeByTwo252.jpg",
#                 "height": 168,
#                 "width": 252,
#                 "legacy": {},
#                 "subType": "mediumThreeByTwo252",
#                 "crop_name": "mediumThreeByTwo252"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mediumThreeByTwo378",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-mediumThreeByTwo378.jpg",
#                 "height": 252,
#                 "width": 378,
#                 "legacy": {},
#                 "subType": "mediumThreeByTwo378",
#                 "crop_name": "mediumThreeByTwo378"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "threeByTwoLargeAt2X",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-threeByTwoLargeAt2X.jpg",
#                 "height": 3444,
#                 "width": 5167,
#                 "legacy": {},
#                 "subType": "threeByTwoLargeAt2X",
#                 "crop_name": "threeByTwoLargeAt2X"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "threeByTwoMediumAt2X",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-threeByTwoMediumAt2X.jpg",
#                 "height": 1000,
#                 "width": 1500,
#                 "legacy": {},
#                 "subType": "threeByTwoMediumAt2X",
#                 "crop_name": "threeByTwoMediumAt2X"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "threeByTwoSmallAt2X",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-threeByTwoSmallAt2X.jpg",
#                 "height": 400,
#                 "width": 600,
#                 "legacy": {},
#                 "subType": "threeByTwoSmallAt2X",
#                 "crop_name": "threeByTwoSmallAt2X"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "articleInline",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-articleInline.jpg",
#                 "height": 127,
#                 "width": 190,
#                 "legacy": {},
#                 "subType": "articleInline",
#                 "crop_name": "articleInline"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "hpSmall",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-hpSmall.jpg",
#                 "height": 109,
#                 "width": 163,
#                 "legacy": {},
#                 "subType": "hpSmall",
#                 "crop_name": "hpSmall"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blogSmallInline",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-blogSmallInline.jpg",
#                 "height": 101,
#                 "width": 151,
#                 "legacy": {},
#                 "subType": "blogSmallInline",
#                 "crop_name": "blogSmallInline"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mediumFlexible177",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-mediumFlexible177.jpg",
#                 "height": 118,
#                 "width": 177,
#                 "legacy": {},
#                 "subType": "mediumFlexible177",
#                 "crop_name": "mediumFlexible177"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSmall",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-videoSmall.jpg",
#                 "height": 281,
#                 "width": 500,
#                 "legacy": {},
#                 "subType": "videoSmall",
#                 "crop_name": "videoSmall"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoHpMedium",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-videoHpMedium.jpg",
#                 "height": 211,
#                 "width": 375,
#                 "legacy": {},
#                 "subType": "videoHpMedium",
#                 "crop_name": "videoHpMedium"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine600",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-videoSixteenByNine600.jpg",
#                 "height": 338,
#                 "width": 600,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine600",
#                 "crop_name": "videoSixteenByNine600"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine540",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-videoSixteenByNine540.jpg",
#                 "height": 304,
#                 "width": 540,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine540",
#                 "crop_name": "videoSixteenByNine540"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine495",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-videoSixteenByNine495.jpg",
#                 "height": 278,
#                 "width": 495,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine495",
#                 "crop_name": "videoSixteenByNine495"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine390",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-videoSixteenByNine390.jpg",
#                 "height": 219,
#                 "width": 390,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine390",
#                 "crop_name": "videoSixteenByNine390"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine1050",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-videoSixteenByNine1050.jpg",
#                 "height": 591,
#                 "width": 1050,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine1050",
#                 "crop_name": "videoSixteenByNine1050"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine480",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-videoSixteenByNine480.jpg",
#                 "height": 270,
#                 "width": 480,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine480",
#                 "crop_name": "videoSixteenByNine480"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine310",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-videoSixteenByNine310.jpg",
#                 "height": 174,
#                 "width": 310,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine310",
#                 "crop_name": "videoSixteenByNine310"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine225",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-videoSixteenByNine225.jpg",
#                 "height": 126,
#                 "width": 225,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine225",
#                 "crop_name": "videoSixteenByNine225"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine96",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-videoSixteenByNine96.jpg",
#                 "height": 54,
#                 "width": 96,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine96",
#                 "crop_name": "videoSixteenByNine96"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine3000",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-videoSixteenByNine3000.jpg",
#                 "height": 1688,
#                 "width": 3000,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine3000",
#                 "crop_name": "videoSixteenByNine3000"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine768",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-videoSixteenByNine768.jpg",
#                 "height": 432,
#                 "width": 768,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine768",
#                 "crop_name": "videoSixteenByNine768"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine150",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-videoSixteenByNine150.jpg",
#                 "height": 84,
#                 "width": 150,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine150",
#                 "crop_name": "videoSixteenByNine150"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNineJumbo1600",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-videoSixteenByNineJumbo1600.jpg",
#                 "height": 900,
#                 "width": 1600,
#                 "legacy": {},
#                 "subType": "videoSixteenByNineJumbo1600",
#                 "crop_name": "videoSixteenByNineJumbo1600"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "miniMoth",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-miniMoth.jpg",
#                 "height": 70,
#                 "width": 151,
#                 "legacy": {},
#                 "subType": "miniMoth",
#                 "crop_name": "miniMoth"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "windowsTile336H",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-windowsTile336H.jpg",
#                 "height": 336,
#                 "width": 694,
#                 "legacy": {},
#                 "subType": "windowsTile336H",
#                 "crop_name": "windowsTile336H"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoFifteenBySeven1305",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-videoFifteenBySeven1305.jpg",
#                 "height": 609,
#                 "width": 1305,
#                 "legacy": {},
#                 "subType": "videoFifteenBySeven1305",
#                 "crop_name": "videoFifteenBySeven1305"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoFifteenBySeven2610",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-videoFifteenBySeven2610.jpg",
#                 "height": 1218,
#                 "width": 2610,
#                 "legacy": {},
#                 "subType": "videoFifteenBySeven2610",
#                 "crop_name": "videoFifteenBySeven2610"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "facebookJumbo",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-facebookJumbo.jpg",
#                 "height": 550,
#                 "width": 1050,
#                 "legacy": {},
#                 "subType": "facebookJumbo",
#                 "crop_name": "facebookJumbo"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "watch308",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-watch308.jpg",
#                 "height": 348,
#                 "width": 312,
#                 "legacy": {},
#                 "subType": "watch308",
#                 "crop_name": "watch308"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "watch268",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-watch268.jpg",
#                 "height": 303,
#                 "width": 272,
#                 "legacy": {},
#                 "subType": "watch268",
#                 "crop_name": "watch268"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "verticalTwoByThree735",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-verticalTwoByThree735.jpg",
#                 "height": 1103,
#                 "width": 735,
#                 "legacy": {},
#                 "subType": "verticalTwoByThree735",
#                 "crop_name": "verticalTwoByThree735"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mobileMasterAt3x",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/09/06/opinion/06douthat1/06douthat1-mobileMasterAt3x.jpg",
#                 "height": 1800,
#                 "width": 1800,
#                 "legacy": {},
#                 "subType": "mobileMasterAt3x",
#                 "crop_name": "mobileMasterAt3x"
#             }
#         ],
#         "headline": {
#             "main": "How America Made James Bond \u2018Woke\u2019",
#             "kicker": "Ross Douthat",
#             "content_kicker": null,
#             "print_headline": null,
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Bond, James (Fictional Character)",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Conservatism (US Politics)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Great Britain Withdrawal from EU (Brexit)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Right-Wing Extremism and Alt-Right",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "glocations",
#                 "value": "Great Britain",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "glocations",
#                 "value": "Canada",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "organizations",
#                 "value": "Conservative Party (Great Britain)",
#                 "rank": 7,
#                 "major": "N"
#             },
#             {
#                 "name": "organizations",
#                 "value": "Conservative Party (Canada)",
#                 "rank": 8,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Politics and Government",
#                 "rank": 9,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Immigration and Emigration",
#                 "rank": 10,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Christians and Christianity",
#                 "rank": 11,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Euthanasia and Assisted Suicide",
#                 "rank": 12,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Drug Abuse and Traffic",
#                 "rank": 13,
#                 "major": "N"
#             },
#             {
#                 "name": "glocations",
#                 "value": "United States",
#                 "rank": 14,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-09-06T09:02:08+0000",
#         "document_type": "article",
#         "news_desk": "OpEd",
#         "section_name": "Opinion",
#         "subsection_name": "Columnists",
#         "byline": {
#             "original": "By Ross Douthat",
#             "person": [
#                 {
#                     "firstname": "Ross",
#                     "middlename": null,
#                     "lastname": "Douthat",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "type_of_material": "Op-Ed",
#         "_id": "nyt://article/c535bb5c-d494-5f63-803d-166cfed9d605",
#         "word_count": 1388,
#         "uri": "nyt://article/c535bb5c-d494-5f63-803d-166cfed9d605"
#     },
#     {
#         "abstract": "Jake Roxander\u2019s soaring Puck in \u201cThe Dream\u201d was the highlight of American Ballet Theater\u2019s final two programs this fall, the first season programmed by Susan Jaffe.",
#         "web_url": "https://www.nytimes.com/2023/10/30/arts/dance/american-ballet-theater.html",
#         "snippet": "Jake Roxander\u2019s soaring Puck in \u201cThe Dream\u201d was the highlight of American Ballet Theater\u2019s final two programs this fall, the first season programmed by Susan Jaffe.",
#         "lead_paragraph": "Mendelssohn\u2019s music for \u201cA Midsummer Night\u2019s Dream\u201d is full of sweet thunder and other wonderful noises. A cartoon sound effect for jumping isn\u2019t among them. Yet when American Ballet Theater performed Frederick Ashton\u2019s ballet \u201cThe Dream\u201d last Saturday, every time Jake Roxander\u2019s Puck took to the air, I could swear I heard one: \u201cboing!\u201d",
#         "print_section": "C",
#         "print_page": "6",
#         "source": "The New York Times",
#         "multimedia": [
#             {
#                 "rank": 0,
#                 "subtype": "xlarge",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/11/01/multimedia/30abt-roxander-vmlz/30abt-roxander-vmlz-articleLarge.jpg",
#                 "height": 468,
#                 "width": 600,
#                 "legacy": {
#                     "xlarge": "images/2023/11/01/multimedia/30abt-roxander-vmlz/30abt-roxander-vmlz-articleLarge.jpg",
#                     "xlargewidth": 600,
#                     "xlargeheight": 468
#                 },
#                 "subType": "xlarge",
#                 "crop_name": "articleLarge"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "popup",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/11/01/multimedia/30abt-roxander-vmlz/30abt-roxander-vmlz-popup.jpg",
#                 "height": 500,
#                 "width": 641,
#                 "legacy": {},
#                 "subType": "popup",
#                 "crop_name": "popup"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blog480",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/11/01/multimedia/30abt-roxander-vmlz/30abt-roxander-vmlz-blog480.jpg",
#                 "height": 375,
#                 "width": 480,
#                 "legacy": {},
#                 "subType": "blog480",
#                 "crop_name": "blog480"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blog533",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/11/01/multimedia/30abt-roxander-vmlz/30abt-roxander-vmlz-blog533.jpg",
#                 "height": 416,
#                 "width": 533,
#                 "legacy": {},
#                 "subType": "blog533",
#                 "crop_name": "blog533"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blog427",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/11/01/multimedia/30abt-roxander-vmlz/30abt-roxander-vmlz-blog427.jpg",
#                 "height": 333,
#                 "width": 427,
#                 "legacy": {},
#                 "subType": "blog427",
#                 "crop_name": "blog427"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "tmagSF",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/11/01/multimedia/30abt-roxander-vmlz/30abt-roxander-vmlz-tmagSF.jpg",
#                 "height": 282,
#                 "width": 362,
#                 "legacy": {},
#                 "subType": "tmagSF",
#                 "crop_name": "tmagSF"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "tmagArticle",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/11/01/multimedia/30abt-roxander-vmlz/30abt-roxander-vmlz-tmagArticle.jpg",
#                 "height": 462,
#                 "width": 592,
#                 "legacy": {},
#                 "subType": "tmagArticle",
#                 "crop_name": "tmagArticle"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "slide",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/11/01/multimedia/30abt-roxander-vmlz/30abt-roxander-vmlz-slide.jpg",
#                 "height": 468,
#                 "width": 600,
#                 "legacy": {},
#                 "subType": "slide",
#                 "crop_name": "slide"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "jumbo",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/11/01/multimedia/30abt-roxander-vmlz/30abt-roxander-vmlz-jumbo.jpg",
#                 "height": 799,
#                 "width": 1024,
#                 "legacy": {},
#                 "subType": "jumbo",
#                 "crop_name": "jumbo"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "superJumbo",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/11/01/multimedia/30abt-roxander-vmlz/30abt-roxander-vmlz-superJumbo.jpg",
#                 "height": 1598,
#                 "width": 2048,
#                 "legacy": {},
#                 "subType": "superJumbo",
#                 "crop_name": "superJumbo"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blog225",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/11/01/multimedia/30abt-roxander-vmlz/30abt-roxander-vmlz-blog225.jpg",
#                 "height": 176,
#                 "width": 225,
#                 "legacy": {},
#                 "subType": "blog225",
#                 "crop_name": "blog225"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master1050",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/11/01/multimedia/30abt-roxander-vmlz/30abt-roxander-vmlz-master1050.jpg",
#                 "height": 819,
#                 "width": 1050,
#                 "legacy": {},
#                 "subType": "master1050",
#                 "crop_name": "master1050"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master675",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/11/01/multimedia/30abt-roxander-vmlz/30abt-roxander-vmlz-master675.jpg",
#                 "height": 527,
#                 "width": 675,
#                 "legacy": {},
#                 "subType": "master675",
#                 "crop_name": "master675"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master495",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
# ...
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2018/02/26/opinion/26stoneWeb/26stoneWeb-facebookJumbo.jpg",
#                 "height": 550,
#                 "width": 1050,
#                 "legacy": {},
#                 "subType": "facebookJumbo",
#                 "crop_name": "facebookJumbo"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "watch308",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2018/02/26/opinion/26stoneWeb/26stoneWeb-watch308.jpg",
#                 "height": 348,
#                 "width": 312,
#                 "legacy": {},
#                 "subType": "watch308",
#                 "crop_name": "watch308"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "watch268",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2018/02/26/opinion/26stoneWeb/26stoneWeb-watch268.jpg",
#                 "height": 303,
#                 "width": 272,
#                 "legacy": {},
#                 "subType": "watch268",
#                 "crop_name": "watch268"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "verticalTwoByThree735",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2018/02/26/opinion/26stoneWeb/26stoneWeb-verticalTwoByThree735.jpg",
#                 "height": 1103,
#                 "width": 735,
#                 "legacy": {},
#                 "subType": "verticalTwoByThree735",
#                 "crop_name": "verticalTwoByThree735"
#             }
#         ],
#         "headline": {
#             "main": "James Bond Is a Wimp",
#             "kicker": "The Stone",
#             "content_kicker": null,
#             "print_headline": null,
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Women and Girls",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "#MeToo Movement",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Philosophy",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Books and Literature",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2018-02-26T10:45:24+0000",
#         "document_type": "article",
#         "news_desk": "OpEd",
#         "section_name": "Opinion",
#         "byline": {
#             "original": "By George Yancy",
#             "person": [
#                 {
#                     "firstname": "George",
#                     "middlename": null,
#                     "lastname": "Yancy",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "type_of_material": "Op-Ed",
#         "_id": "nyt://article/adfd7814-f245-569f-a45e-235056e43dd6",
#         "word_count": 2669,
#         "uri": "nyt://article/adfd7814-f245-569f-a45e-235056e43dd6"
#     },
#     {
#         "abstract": "Article on actors who have played James Bond in past and considers those who might take over role when Pierce Brosnan finishes his next and last Bond film; says Hugh Jackman is viable candidate, but Chow Yun-Fat might be better choice; photos (M)",
#         "web_url": "https://www.nytimes.com/2003/11/09/movies/film-auditioning-the-next-james-bond.html",
#         "snippet": "Article on actors who have played James Bond in past and considers those who might take over role when Pierce Brosnan finishes his next and last Bond film; says Hugh Jackman is viable candidate, but Chow Yun-Fat might be better choice; photos (M)",
#         "lead_paragraph": "AS 2003 rolls to an end, the phrase ''Academy Award winner'' will appear more frequently in movie ads, Tom Cruise will gaze winsomely from the cover of every magazine except Cook's Illustrated and Black Enterprise, and the annual, unofficial ''Who will be the next James Bond?'' sweepstakes will commence.",
#         "print_section": "2",
#         "print_page": "30",
#         "source": "The New York Times",
#         "multimedia": [],
#         "headline": {
#             "main": "Auditioning the Next James Bond",
#             "kicker": "FILM",
#             "content_kicker": null,
#             "print_headline": "FILM; Auditioning the Next James Bond",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "persons",
#                 "value": "Jackman, Hugh",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Bond, James",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Chow Yun-Fat",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Brosnan, Pierce",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "MOTION PICTURES",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2003-11-09T05:00:00+0000",
#         "document_type": "article",
#         "news_desk": "Arts and Leisure Desk",
#         "section_name": "Movies",
#         "byline": {
#             "original": "By Elvis Mitchell",
#             "person": [
#                 {
#                     "firstname": "Elvis",
#                     "middlename": null,
#                     "lastname": "Mitchell",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "type_of_material": "News",
#         "_id": "nyt://article/4347a54a-0e84-5df7-b331-e221d8ff8f0f",
#         "word_count": 1160,
#         "uri": "nyt://article/4347a54a-0e84-5df7-b331-e221d8ff8f0f"
#     },
#     {
#         "abstract": "A tour of filming locations used in \"Dr. No\" and \"Live and Let Die\" on the island where Ian Fleming wrote the novels.",
#         "web_url": "https://www.nytimes.com/video/travel/1194832287632/on-the-trail-of-james-bond-s-jamaica.html",
#         "snippet": "A tour of filming locations used in \"Dr. No\" and \"Live and Let Die\" on the island where Ian Fleming wrote the novels.",
#         "lead_paragraph": "A tour of filming locations used in \"Dr. No\" and \"Live and Let Die\" on the island where Ian Fleming wrote the novels.",
#         "source": "The New York Times",
#         "multimedia": [
#             {
#                 "rank": 0,
#                 "subtype": "wide",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2008/11/07/travel/newbond190.jpg",
#                 "height": 126,
#                 "width": 190,
#                 "legacy": {
#                     "widewidth": 190,
#                     "wideheight": 126,
#                     "wide": "images/2008/11/07/travel/newbond190.jpg"
#                 },
#                 "subType": "wide",
#                 "crop_name": "thumbWide"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoThumb",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2008/11/07/travel/new75x50.jpg",
#                 "height": 50,
#                 "width": 75,
#                 "legacy": {},
#                 "subType": "videoThumb",
#                 "crop_name": "videoThumb"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSmall",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2008/11/07/travel/newbond312.jpg",
#                 "height": 176,
#                 "width": 312,
#                 "legacy": {},
#                 "subType": "videoSmall",
#                 "crop_name": "videoSmall"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "thumbnail",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2008/11/07/travel/newbond75.jpg",
#                 "height": 75,
#                 "width": 75,
#                 "legacy": {
#                     "thumbnail": "images/2008/11/07/travel/newbond75.jpg",
#                     "thumbnailwidth": 75,
#                     "thumbnailheight": 75
#                 },
#                 "subType": "thumbnail",
#                 "crop_name": "thumbStandard"
#             }
#         ],
#         "headline": {
#             "main": "On the Trail of James Bond's Jamaica",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": null,
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Travel and Vacations",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Fleming, Ian",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "glocations",
#                 "value": "Jamaica",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2008-11-07T21:28:20+0000",
#         "document_type": "multimedia",
#         "news_desk": "Travel",
#         "section_name": "Travel",
#         "byline": {
#             "original": "Vijai Singh",
#             "person": [
#                 {
#                     "firstname": "Vijai",
#                     "middlename": null,
#                     "lastname": "Singh",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "type_of_material": "Video",
#         "_id": "nyt://video/9c4b7edd-1fbd-5a58-9d56-11a7c94cd653",
#         "word_count": 0,
#         "uri": "nyt://video/9c4b7edd-1fbd-5a58-9d56-11a7c94cd653"
#     },
#     {
#         "abstract": "Article on four new DVD box sets that include all 20 James Bond films; photo (M)",
#         "web_url": "https://www.nytimes.com/2006/11/05/arts/movies/holiday-moviesdvds-the-james-bond-ultimate-collection.html",
#         "snippet": "Article on four new DVD box sets that include all 20 James Bond films; photo (M)",
#         "lead_paragraph": "Correction Appended",
#         "print_section": "A",
#         "print_page": "2",
#         "source": "The New York Times",
#         "multimedia": [],
#         "headline": {
#             "main": "The James Bond Ultimate Collection",
#             "kicker": "HOLIDAY MOVIES/DVDS",
#             "content_kicker": null,
#             "print_headline": "HOLIDAY MOVIES/DVDS; The James Bond Ultimate Collection",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "MOTION PICTURES",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Recordings and Downloads (Video)",
#                 "rank": 2,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2006-11-05T05:00:00+0000",
#         "document_type": "article",
#         "news_desk": "Arts and Leisure Desk",
#         "section_name": "Arts",
#         "byline": {
#             "original": "By Charles Taylor",
#             "person": [
#                 {
#                     "firstname": "Charles",
#                     "middlename": null,
#                     "lastname": "Taylor",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "type_of_material": "News",
#         "_id": "nyt://article/2be7a139-13f1-545a-ad7d-22cd14d564c2",
#         "word_count": 353,
#         "uri": "nyt://article/2be7a139-13f1-545a-ad7d-22cd14d564c2"
#     },
#     {
#         "abstract": "Beyond Villa is a sprawling 65,000-square-foot house near Phuket, Thailand owned by Eric Levine.",
#         "web_url": "https://www.nytimes.com/slideshow/2009/09/15/realestate/0920-phuket_index.html",
#         "snippet": "Beyond Villa is a sprawling 65,000-square-foot house near Phuket, Thailand owned by Eric Levine.",
#         "lead_paragraph": "Beyond Villa is a sprawling 65,000-square-foot house near Phuket, Thailand owned by Eric Levine.",
#         "source": "The New York Times",
#         "multimedia": [
#             {
#                 "rank": 0,
#                 "subtype": "wide",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "packages/images/photo/2009/09/14/0920-phuket/0920-phuket-B.JPG",
#                 "height": 126,
#                 "width": 190,
#                 "legacy": {
#                     "widewidth": 190,
#                     "wideheight": 126,
#                     "wide": "packages/images/photo/2009/09/14/0920-phuket/0920-phuket-B.JPG"
#                 },
#                 "subType": "wide",
#                 "crop_name": "thumbWide"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "thumbnail",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "packages/images/photo/2009/09/14/0920-phuket/0920-phuket-S.JPG",
#                 "height": 75,
#                 "width": 75,
#                 "legacy": {
#                     "thumbnail": "packages/images/photo/2009/09/14/0920-phuket/0920-phuket-S.JPG",
#                     "thumbnailwidth": 75,
#                     "thumbnailheight": 75
#                 },
#                 "subType": "thumbnail",
#                 "crop_name": "thumbStandard"
#             }
#         ],
#         "headline": {
#             "main": "James Bond Meets Asia",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": null,
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [],
#         "pub_date": "2009-09-15T20:25:02+0000",
#         "document_type": "multimedia",
#         "news_desk": "Real Estate",
#         "section_name": "Real Estate",
#         "byline": {
#             "original": null,
#             "person": [],
#             "organization": null
#         },
#         "type_of_material": "Slideshow",
#         "_id": "nyt://slideshow/a3337d72-b26f-5f39-bdc3-12b1c143871b",
#         "word_count": 0,
#         "slideshow_credits": "James Robert Fuller for The New York Times",
#         "uri": "nyt://slideshow/a3337d72-b26f-5f39-bdc3-12b1c143871b"
#     }
# ]

# %%
# Create an empty list to store the reviews
articles_list = []

# loop through pages 0-19
for page in range(0,20):
    query_url = query_url = url + "api-key=" + nyt_api_key + "&q=" + query
 
    # create query with page number
    query_url = f"{query_url}&page={str(page)}"
    
    # Make a "GET" request and retrieve the JSON
    articles = requests.get(query_url).json()
    
    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)
    
    # Try and save the reviews to the reviews_list
    for article in articles["response"]["docs"]:
        
        # loop through the reviews["response"]["docs"] and append each review to the list
        reviews_list.append(article["review"])
        # Print the page that was just retrieved
        print(f"Checked page {page}")

    # Print the page number that had no results then break from the loop
    print(f"Retrieved page {page}")

    # Check if there are no results on the page and break from the loop
    # API results show 10 articles at a time
    if len(articles["response"]["docs"]) == 0:
        print(f"No results found on page {page}")
        break  

    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)

    # Save the reviews to the reviews_list
    for article in articles["response"]["docs"]:
        reviews_list.append(article["review"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 21
#      17 # Try and save the reviews to the reviews_list
#      18 for article in articles["response"]["docs"]:
#      19
#      20     # loop through the reviews["response"]["docs"] and append each review to the list
# ---> 21     reviews_list.append(article["review"])
#      22     # Print the page that was just retrieved
#      23     print(f"Checked page {page}")
#
# KeyError: 'review'

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",
#         "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Attachment Diaries",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Attachment Diaries (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Diment, Valentin Javier",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-25T11:00:03+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 295
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/whats-love-got-to-do-with-it-review.html",
#         "snippet": "Two childhood friends navigate cultural differences in this pleasantly uncontentious romantic comedy.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018What\u2019s Love Got to Do With It?\u2019 Probably a Lot",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "What\u2019s Love Got to Do With It?",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kapur, Shekhar",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "James, Lily",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Azmi, Shabana",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Thompson, Emma",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T17:16:45+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 287
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/you-can-live-forever-review.html",
#         "snippet": "Religion comes between two girls falling in love in the 1990s in this sweet coming-of-age film bathed in grunge hues.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018You Can Live Forever\u2019 Review: Do You Love Me Now?",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "You Can Live Forever",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "You Can Live Forever (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Slutsky, Mark",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Watts, Sarah (Film Director)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "O'Driscoll, Anwen",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Laporte, June (Actor)",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T11:00:08+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 294
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/21/movies/a-tourists-guide-to-love-review.html",
#         "snippet": "Rachael Leigh Cook stars in this bland rom-com as a travel executive exploring Vietnam and getting over a breakup.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018A Tourist\u2019s Guide to Love\u2019 Review: A Wearyingly Familiar Trip",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "A Tourist\u2019s  Guide to Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "A Tourist's Guide to Love (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Tsuchida, Steven",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Cook, Rachael Leigh",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-21T07:03:25+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 276
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/20/movies/other-peoples-children-review.html",
#         "snippet": "A radiant Virginie Efira stars as a Parisian teacher who blissfully falls for a man and his 4-year-old daughter, complicating everyone\u2019s lives.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Other People\u2019s Children\u2019 Review: True Romance",
#             "kicker": "Critic\u2019s pick",
#             "content_kicker": null,
#             "print_headline": "Intoxicating Love With a Sobering Turn",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Zlotowski, Rebecca",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Other People's Children (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-20T15:35:13+0000",
#         "byline": {
#             "original": "By Manohla Dargis",
#             "person": [
#                 {
#                     "firstname": "Manohla",
#                     "middlename": null,
#                     "lastname": "Dargis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 801
#     }
# ]

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# 3    Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ..                                                 ...                 ...
# 195  This moody romance stars Tatiana Maslany (“Orp...  The New York Times
# 196  A nurse travels to the Ottoman Empire on the e...  The New York Times
# 197  Josh Kornbluth runs afoul of the Internal Reve...  The New York Times
# 198  A messed-up heroine is asked to choose between...  The New York Times
# 199  This documentary profiles distinctive street c...  The New York Times
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4    [{'name': 'subject', 'value': 'Movies', 'rank'...
# ..                                                 ...
# 195  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 196  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 197  [{'name': 'creative_works', 'value': 'Love & T...
# 198  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 199  [{'name': 'creative_works', 'value': 'Kedi (Mo...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T17:16:45+0000         287
# 2    2023-05-04T11:00:08+0000         294
# 3    2023-04-21T07:03:25+0000         276
# 4    2023-04-20T15:35:13+0000         801
# ..                        ...         ...
# 195  2017-03-09T21:54:58+0000         251
# 196  2017-03-09T21:53:12+0000         267
# 197  2017-03-02T21:44:18+0000         246
# 198  2017-02-16T21:45:50+0000         256
# 199  2017-02-09T16:21:39+0000         274
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ..                                                 ...             ...
# 195  Review: A Combustible Pair Find Love in ‘The O...            None
# 196  Review: Love as the World Wars, in ‘The Ottoma...            None
# 197  Review: It’s All Mirth and Taxes in ‘Love & Ta...            None
# 198  Review: ‘Everybody Loves Somebody,’ a Rom-Com ...            None
# 199  Review: Cute Cats of ‘Kedi,’ Rekindling a ‘Lov...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 195                    None
# 196                    None
# 197                    None
# 198                    None
# 199                    None
#
#                                headline.print_headline headline.name  \
# 0                               The Attachment Diaries          None
# 1                       What’s Love Got to Do With It?          None
# 2                                 You Can Live Forever          None
# 3                           A Tourist’s  Guide to Love          None
# 4               Intoxicating Love With a Sobering Turn          None
# ..                                                 ...           ...
# 195  Review: A Combustible Pair Find Love in ‘The O...          None
# 196  Review: Love as the World Wars, in ‘The Ottoma...          None
# 197                   It’s Inevitable, Mirth and Taxes          None
# 198                           Everybody Loves Somebody          None
# 199                                               Kedi          None
#
#     headline.seo headline.sub           byline.original  \
# 0           None         None    By Jeannette Catsoulis
# 1           None         None    By Jeannette Catsoulis
# 2           None         None  By Elisabeth Vincentelli
# 3           None         None  By Elisabeth Vincentelli
# 4           None         None         By Manohla Dargis
# ..           ...          ...                       ...
# 195         None         None           By Andy Webster
# 196         None         None        By Neil Genzlinger
# 197         None         None         By Ken Jaworowski
# 198         None         None    By Jeannette Catsoulis
# 199         None         None            By Glenn Kenny
#
#                                          byline.person byline.organization
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Andy', 'middlename': None, 'la...                None
# 196  [{'firstname': 'Neil', 'middlename': None, 'la...                None
# 197  [{'firstname': 'Ken', 'middlename': None, 'las...                None
# 198  [{'firstname': 'Jeannette', 'middlename': None...                None
# 199  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
#
# [200 rows x 16 columns]

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# 3    Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ..                                                 ...                 ...
# 195  This moody romance stars Tatiana Maslany (“Orp...  The New York Times
# 196  A nurse travels to the Ottoman Empire on the e...  The New York Times
# 197  Josh Kornbluth runs afoul of the Internal Reve...  The New York Times
# 198  A messed-up heroine is asked to choose between...  The New York Times
# 199  This documentary profiles distinctive street c...  The New York Times
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4    [{'name': 'subject', 'value': 'Movies', 'rank'...
# ..                                                 ...
# 195  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 196  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 197  [{'name': 'creative_works', 'value': 'Love & T...
# 198  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 199  [{'name': 'creative_works', 'value': 'Kedi (Mo...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T17:16:45+0000         287
# 2    2023-05-04T11:00:08+0000         294
# 3    2023-04-21T07:03:25+0000         276
# 4    2023-04-20T15:35:13+0000         801
# ..                        ...         ...
# 195  2017-03-09T21:54:58+0000         251
# 196  2017-03-09T21:53:12+0000         267
# 197  2017-03-02T21:44:18+0000         246
# 198  2017-02-16T21:45:50+0000         256
# 199  2017-02-09T16:21:39+0000         274
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ..                                                 ...             ...
# 195  Review: A Combustible Pair Find Love in ‘The O...            None
# 196  Review: Love as the World Wars, in ‘The Ottoma...            None
# 197  Review: It’s All Mirth and Taxes in ‘Love & Ta...            None
# 198  Review: ‘Everybody Loves Somebody,’ a Rom-Com ...            None
# 199  Review: Cute Cats of ‘Kedi,’ Rekindling a ‘Lov...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 195                    None
# 196                    None
# 197                    None
# 198                    None
# 199                    None
#
#                                headline.print_headline headline.name  \
# 0                               The Attachment Diaries          None
# 1                       What’s Love Got to Do With It?          None
# 2                                 You Can Live Forever          None
# 3                           A Tourist’s  Guide to Love          None
# 4               Intoxicating Love With a Sobering Turn          None
# ..                                                 ...           ...
# 195  Review: A Combustible Pair Find Love in ‘The O...          None
# 196  Review: Love as the World Wars, in ‘The Ottoma...          None
# 197                   It’s Inevitable, Mirth and Taxes          None
# 198                           Everybody Loves Somebody          None
# 199                                               Kedi          None
#
#     headline.seo headline.sub           byline.original  \
# 0           None         None    By Jeannette Catsoulis
# 1           None         None    By Jeannette Catsoulis
# 2           None         None  By Elisabeth Vincentelli
# 3           None         None  By Elisabeth Vincentelli
# 4           None         None         By Manohla Dargis
# ..           ...          ...                       ...
# 195         None         None           By Andy Webster
# 196         None         None        By Neil Genzlinger
# 197         None         None         By Ken Jaworowski
# 198         None         None    By Jeannette Catsoulis
# 199         None         None            By Glenn Kenny
#
#                                          byline.person byline.organization  \
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Andy', 'middlename': None, 'la...                None
# 196  [{'firstname': 'Neil', 'middlename': None, 'la...                None
# 197  [{'firstname': 'Ken', 'middlename': None, 'las...                None
# 198  [{'firstname': 'Jeannette', 'middlename': None...                None
# 199  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
#
#                                              title
# 0                           The Attachment Diaries
# 1    What’s Love Got to Do With It?’ Probably a Lo
# 2                             You Can Live Forever
# 3                        A Tourist’s Guide to Love
# 4                          Other People’s Children
# ..                                             ...
# 195                                 The Other Half
# 196                         The Ottoman Lieutenant
# 197                                   Love & Taxes
# 198  Everybody Loves Somebody,’ a Rom-Com With Bit
# 199              Kedi,’ Rekindling a ‘Love of Life
#
# [200 rows x 17 columns]

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# 3    Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ..                                                 ...                 ...
# 195  This moody romance stars Tatiana Maslany (“Orp...  The New York Times
# 196  A nurse travels to the Ottoman Empire on the e...  The New York Times
# 197  Josh Kornbluth runs afoul of the Internal Reve...  The New York Times
# 198  A messed-up heroine is asked to choose between...  The New York Times
# 199  This documentary profiles distinctive street c...  The New York Times
#
#                                               keywords  \
# 0    subject: Movies;creative_works: The Attachment...
# 1    subject: Movies;persons: Kapur, Shekhar;person...
# 2    subject: Movies;creative_works: You Can Live F...
# 3    subject: Movies;creative_works: A Tourist's Gu...
# 4    subject: Movies;persons: Zlotowski, Rebecca;cr...
# ..                                                 ...
# 195  subject: Movies;creative_works: The Other Half...
# 196  subject: Movies;creative_works: The Ottoman Li...
# 197  creative_works: Love & Taxes (Movie);persons: ...
# 198  subject: Movies;creative_works: Everybody Love...
# 199  creative_works: Kedi (Movie);subject: Document...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T17:16:45+0000         287
# 2    2023-05-04T11:00:08+0000         294
# 3    2023-04-21T07:03:25+0000         276
# 4    2023-04-20T15:35:13+0000         801
# ..                        ...         ...
# 195  2017-03-09T21:54:58+0000         251
# 196  2017-03-09T21:53:12+0000         267
# 197  2017-03-02T21:44:18+0000         246
# 198  2017-02-16T21:45:50+0000         256
# 199  2017-02-09T16:21:39+0000         274
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ..                                                 ...             ...
# 195  Review: A Combustible Pair Find Love in ‘The O...            None
# 196  Review: Love as the World Wars, in ‘The Ottoma...            None
# 197  Review: It’s All Mirth and Taxes in ‘Love & Ta...            None
# 198  Review: ‘Everybody Loves Somebody,’ a Rom-Com ...            None
# 199  Review: Cute Cats of ‘Kedi,’ Rekindling a ‘Lov...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 195                    None
# 196                    None
# 197                    None
# 198                    None
# 199                    None
#
#                                headline.print_headline headline.name  \
# 0                               The Attachment Diaries          None
# 1                       What’s Love Got to Do With It?          None
# 2                                 You Can Live Forever          None
# 3                           A Tourist’s  Guide to Love          None
# 4               Intoxicating Love With a Sobering Turn          None
# ..                                                 ...           ...
# 195  Review: A Combustible Pair Find Love in ‘The O...          None
# 196  Review: Love as the World Wars, in ‘The Ottoma...          None
# 197                   It’s Inevitable, Mirth and Taxes          None
# 198                           Everybody Loves Somebody          None
# 199                                               Kedi          None
#
#     headline.seo headline.sub           byline.original  \
# 0           None         None    By Jeannette Catsoulis
# 1           None         None    By Jeannette Catsoulis
# 2           None         None  By Elisabeth Vincentelli
# 3           None         None  By Elisabeth Vincentelli
# 4           None         None         By Manohla Dargis
# ..           ...          ...                       ...
# 195         None         None           By Andy Webster
# 196         None         None        By Neil Genzlinger
# 197         None         None         By Ken Jaworowski
# 198         None         None    By Jeannette Catsoulis
# 199         None         None            By Glenn Kenny
#
#                                          byline.person byline.organization  \
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Andy', 'middlename': None, 'la...                None
# 196  [{'firstname': 'Neil', 'middlename': None, 'la...                None
# 197  [{'firstname': 'Ken', 'middlename': None, 'las...                None
# 198  [{'firstname': 'Jeannette', 'middlename': None...                None
# 199  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
#
#                                              title
# 0                           The Attachment Diaries
# 1    What’s Love Got to Do With It?’ Probably a Lo
# 2                             You Can Live Forever
# 3                        A Tourist’s Guide to Love
# 4                          Other People’s Children
# ..                                             ...
# 195                                 The Other Half
# 196                         The Ottoman Lieutenant
# 197                                   Love & Taxes
# 198  Everybody Loves Somebody,’ a Rom-Com With Bit
# 199              Kedi,’ Rekindling a ‘Love of Life
#
# [200 rows x 17 columns]

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
titles = ['The Attachment Diaries',
 'What’s Love Got to Do With It?’ Probably a Lo',
 'You Can Live Forever',
 'A Tourist’s Guide to Love',
 'Other People’s Children',
 'One True Loves',
 'The Lost Weekend: A Love Story',
 'A Thousand and One',
 'Your Place or Mine',
 'Love in the Time of Fentanyl',
 'Pamela, a Love Story',
 'In From the Side',
 'After Love',
 'Alcarràs',
 'Nelly & Nadine',
 'Lady Chatterley’s Lover',
 'The Sound of Christmas',
 'The Inspection',
 'Bones and All',
 'My Policeman',
 'About Fate',
 'Waiting for Bojangles',
 'I Love My Dad',
 'A Love Song',
 'Alone Together',
 'Art of Love',
 'The Wheel',
 'Thor: Love and Thunder',
 'Both Sides of the Blade',
 'Fire of Love',
 'Love & Gelato',
 'Stay Prayed Up',
 'Benediction',
 'Dinner in America',
 'In a New York Minute',
 'Anaïs in Love',
 'I Love America',
 'See You Then',
 'La Mami',
 'Love After Love',
 'Deep Water',
 'Lucy and Desi',
 'Cyrano',
 'The In Between',
 'Book of Love',
 'Lingui, the Sacred Bonds',
 'The Pink Cloud',
 'A Journal for Jordan',
 'West Side Story',
 'Aulcie',
 'Love Is Love Is Love',
 'Love Hard',
 'Bergman Island',
 'Hard Luck Love Song',
 'South of Heaven',
 'Wife of a Spy',
 'Happier Than Ever',
 'Together',
 'Annette',
 'Resort to Love',
 'Woodstock 99: Peace, Love and Rage',
 'Casanova, Last Love',
 'Running Against the Wind',
 'Asia',
 'Undine',
 'This Town',
 'Tu Me Manques',
 'Monday',
 'Ride or Die',
 'Future People',
 'Luz',
 'Happily',
 'This Is the Life',
 'To All the Boys: Always and Forever',
 'Young Hearts',
 'Little Fish',
 'Two of Us',
 'Atlantis',
 'Preparations to Be Together',
 'Your Name Engraved Herein',
 'Sylvie’s Love',
 'Ariana Grande: Excuse Me, I Love You',
 'Museum Town',
 'Wild Mountain Thyme',
 'My Psychedelic Love Story',
 '69: The Saga of Danny Hernandez',
 'Ammonite',
 'Love and Monsters',
 'Dick Johnson Is Dead',
 'Love, Guaranteed',
 'Feel the Beat',
 'Babyteeth',
 'Spelling the Dream',
 'A Secret Love',
 'Love Wedding Repeat',
 'Almost Love',
 'Hope Gap',
 'All the Bright Places',
 'The Photograph',
 'You Go to My Head',
 'Ordinary Love',
 'To All the Boys: P.S. I Still Love You',
 'The Woman Who Loves Giraffes',
 'Queen & Slim',
 'Marriage Story',
 'Cyrano, My Love',
 'Pretenders',
 'First Love',
 'Loro',
 'Falling Inn Love',
 'Hot Air',
 'Love, Antosha',
 'Leto',
 'The Tomorrow Man',
 'Asako I & II',
 'The Sun Is Also a Star',
 'Shéhérazade',
 'Long Shot',
 'Clara',
 'Kalank',
 'Rafiki',
 'Diane',
 'Five Feet Apart',
 'Ash Is Purest White',
 'Gloria Bell',
 'Black Mother',
 'The Hole in the Ground',
 'How to Train Your Dragon: The Hidden World',
 'A Tuba to Cuba',
 'Fighting With My Family',
 'Sorry Angel',
 'Berlin, I Love You',
 'Untogether',
 'Cold War',
 'If Beale Street Could Talk',
 'Asher',
 'The Party’s Just Beginning',
 'The Great Pretender',
 'Sicilian Ghost Story',
 'The New Romantic',
 'Pimp',
 'In a Relationship',
 'They’ll Love Me When I’m Dead’ Documents Orson Welles’s Last Fil',
 'Burning,’ Love Ignites a Divided Worl',
 'After Everything,’ a Young Love Blooms in Crisi',
 'Quincy’ Captures a Lifelong Love Affair With Musi',
 'Love, Gilda,’ a Portrait of a Brief and Brilliant Caree',
 'Tea With the Dames,’ Four Legends Dish on Acting and Lov',
 'Bel Canto,’ Music Is the Food of Love and Rebellio',
 'The Citizen,’ an Immigrant Picks a Bad Time to Fall in Lov',
 'Love, Cecil,’ an Aesthete Ahead of His Tim',
 'How to Talk to Girls at Parties',
 'Rogers Park,’ Life and Love in a Chicago Neighborhoo',
 'Love & Bananas,’ Uncovering the Plight of the Asian Elephan',
 'Godard Mon Amour',
 'Submergence,’ a Love Story Sunk by Geopolitic',
 'Love After Love,’ an Unflinching Look at Extended Grie',
 'Outside In',
 'Love, Simon,’ a Glossy Teen Romance, the Hero Has a Secre',
 'Keep the Change,’ Two People With Autism Find Lov',
 'The Party',
 'The Housemaid,’ Twisted Love and Angry Ghosts in Vietna',
 'Forever My Girl,’ a Romance Resumes After a Long Brea',
 'Kangaroo: A Love-Hate Story’ Exposes a Wildlife Massacr',
 'Lover for a Day',
 'Youth,’ the People’s Dance Troupe, in Love and Wa',
 'Killing for Love’ Revisits a Virginia Murder Cas',
 'The Shape of Water’ Is Altogether Wonderfu',
 'Love Beats Rhymes,’ a Hip-Hop Artist Transformed by Poetr',
 'Cuba and the Cameraman’ Lavishes Love on a Country … and Castr',
 'On the Beach at Night Alone’ Zooms in on a Love Affai',
 'Thelma,’ a Woman in Love Can Burn Down the Worl',
 'Hello Again,’ a Movie Musical Ode to Love and Lust Over Decade',
 'It Happened in L.A.,’ All That Questing After Lov',
 'God’s Own Country',
 'The Mountain Between Us',
 'Dina,’ a Differently Abled Love Stor',
 'In Search of Fellini',
 'Woodpeckers,’ a Tale of Love and Agonizing Penal Confinemen',
 'I Do ... Until I Don’t,’ Love and Loathing in Florid',
 'Tales of an Immoral Couple’: Love Means Having to Grow U',
 'After Love’ and Regretting Every Momen',
 'The Last Face',
 'Women Who Kill,’ and May Be in Love With On',
 'False Confessions,’ the Play’s Not Quite the Thin',
 'Review: Those Movies, Himself — Bertrand Tavernier’s Tour of French Cinem',
 'The Big Sick,’ Comedy Is Hard, Love Harde',
 'Lost in Paris',
 'Vincent N Roxxy,’ Love Is in the Air, N So Is Fea',
 'Everything, Everything’ Pits Love Against Diseas',
 'Hounds of Love’ Is Tense and Deadly Down Unde',
 'Harold and Lillian’ Introduces a Hollywood Power Coupl',
 'The Happiest Day in the Life of Olli Maki,’ Love and Life on the Rope',
 'The Promise’ Finds a Love Triangle in Constantinopl',
 'Frantz,’ a Mysterious Frenchman and the Wounds of Wa',
 'The Other Half',
 'The Ottoman Lieutenant',
 'Love & Taxes',
 'Everybody Loves Somebody,’ a Rom-Com With Bit',
 'Kedi,’ Rekindling a ‘Love of Life']

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key
print(tmdb_key_string)
#below code works
#tmdb_api_key = os.getenv("TMDB_API_KEY")
#type(tmdb_api_key)
# Out:
# &api_key=89e4250eebe3ec4d91babdc01a7cfa07

# %%
# Create an empty list to store the results
results = []

# Create a request counter to sleep the requests after a multiple
# of 50 requests
request_counter = 0

# Loop through the titles
for title in titles:
    # Check if we need to sleep before making a request
    if request_counter % 50 == 0 and request_counter != 0:
        time.sleep(10)  # Sleep for 10 seconds

    # Add 1 to the request counter
    request_counter += 1
    
    try:
    # Perform a "GET" request for The Movie Database
        response = requests.get(f"https://api.themoviedb.org/3/search/movie?api_key={api_key}&query={title}")
        
        # Use the except clause to print out a statement if a movie is not found
        if response.status_code == 404:
            print(f"Movie '{title}' not found.")
            continue
        
        # Get movie id
        movie_id = response.json()["results"][0]["id"]
        
        # Make a request for the full movie details
        response = requests.get(f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={api_key}")
        
        # Execute "GET" request with url
        if response.status_code == 200:
            # Extract the genre names into a list
            genres = [genre["name"] for genre in response.json()["genres"]]
            
            # Extract the spoken_languages' English name into a list
            spoken_languages = [language["english_name"] for language in response.json()["spoken_languages"]]
            
            # Extract the production_countries' name into a list
            production_countries = [country["name"] for country in response.json()["production_countries"]]
            
            # Add the relevant data to a dictionary and append it to the results list
            result = {
                "title": title,
                "genres": genres,
                "spoken_languages": spoken_languages,
                "production_countries": production_countries
            }
            results.append(result)
            
            # Print out the title that was found
            print(f"Movie '{title}' found.")
        else:
            print(f"Error retrieving movie '{title}'.")
    except:
        print(f"Error retrieving movie '{title}'.")
# Out:
# Error retrieving movie 'The Attachment Diaries'.
# Error retrieving movie 'What’s Love Got to Do With It?’ Probably a Lo'.
# Error retrieving movie 'You Can Live Forever'.
# Error retrieving movie 'A Tourist’s Guide to Love'.
# Error retrieving movie 'Other People’s Children'.
# Error retrieving movie 'One True Loves'.
# Error retrieving movie 'The Lost Weekend: A Love Story'.
# Error retrieving movie 'A Thousand and One'.
# Error retrieving movie 'Your Place or Mine'.
# Error retrieving movie 'Love in the Time of Fentanyl'.
# Error retrieving movie 'Pamela, a Love Story'.
# Error retrieving movie 'In From the Side'.
# Error retrieving movie 'After Love'.
# Error retrieving movie 'Alcarràs'.
# Error retrieving movie 'Nelly & Nadine'.
# Error retrieving movie 'Lady Chatterley’s Lover'.
# Error retrieving movie 'The Sound of Christmas'.
# Error retrieving movie 'The Inspection'.
# Error retrieving movie 'Bones and All'.
# Error retrieving movie 'My Policeman'.
# Error retrieving movie 'About Fate'.
# Error retrieving movie 'Waiting for Bojangles'.
# Error retrieving movie 'I Love My Dad'.
# Error retrieving movie 'A Love Song'.
# Error retrieving movie 'Alone Together'.
# Error retrieving movie 'Art of Love'.
# Error retrieving movie 'The Wheel'.
# Error retrieving movie 'Thor: Love and Thunder'.
# Error retrieving movie 'Both Sides of the Blade'.
# Error retrieving movie 'Fire of Love'.
# Error retrieving movie 'Love & Gelato'.
# Error retrieving movie 'Stay Prayed Up'.
# Error retrieving movie 'Benediction'.
# Error retrieving movie 'Dinner in America'.
# Error retrieving movie 'In a New York Minute'.
# Error retrieving movie 'Anaïs in Love'.
# Error retrieving movie 'I Love America'.
# Error retrieving movie 'See You Then'.
# Error retrieving movie 'La Mami'.
# Error retrieving movie 'Love After Love'.
# Error retrieving movie 'Deep Water'.
# Error retrieving movie 'Lucy and Desi'.
# Error retrieving movie 'Cyrano'.
# Error retrieving movie 'The In Between'.
# Error retrieving movie 'Book of Love'.
# Error retrieving movie 'Lingui, the Sacred Bonds'.
# Error retrieving movie 'The Pink Cloud'.
# Error retrieving movie 'A Journal for Jordan'.
# Error retrieving movie 'West Side Story'.
# Error retrieving movie 'Aulcie'.
# Error retrieving movie 'Love Is Love Is Love'.
# Error retrieving movie 'Love Hard'.
# Error retrieving movie 'Bergman Island'.
# Error retrieving movie 'Hard Luck Love Song'.
# Error retrieving movie 'South of Heaven'.
# Error retrieving movie 'Wife of a Spy'.
# Error retrieving movie 'Happier Than Ever'.
# Error retrieving movie 'Together'.
# Error retrieving movie 'Annette'.
# Error retrieving movie 'Resort to Love'.
# Error retrieving movie 'Woodstock 99: Peace, Love and Rage'.
# Error retrieving movie 'Casanova, Last Love'.
# Error retrieving movie 'Running Against the Wind'.
# Error retrieving movie 'Asia'.
# Error retrieving movie 'Undine'.
# Error retrieving movie 'This Town'.
# Error retrieving movie 'Tu Me Manques'.
# Error retrieving movie 'Monday'.
# Error retrieving movie 'Ride or Die'.
# Error retrieving movie 'Future People'.
# Error retrieving movie 'Luz'.
# Error retrieving movie 'Happily'.
# Error retrieving movie 'This Is the Life'.
# Error retrieving movie 'To All the Boys: Always and Forever'.
# Error retrieving movie 'Young Hearts'.
# Error retrieving movie 'Little Fish'.
# Error retrieving movie 'Two of Us'.
# Error retrieving movie 'Atlantis'.
# Error retrieving movie 'Preparations to Be Together'.
# Error retrieving movie 'Your Name Engraved Herein'.
# Error retrieving movie 'Sylvie’s Love'.
# Error retrieving movie 'Ariana Grande: Excuse Me, I Love You'.
# Error retrieving movie 'Museum Town'.
# Error retrieving movie 'Wild Mountain Thyme'.
# Error retrieving movie 'My Psychedelic Love Story'.
# Error retrieving movie '69: The Saga of Danny Hernandez'.
# Error retrieving movie 'Ammonite'.
# Error retrieving movie 'Love and Monsters'.
# Error retrieving movie 'Dick Johnson Is Dead'.
# Error retrieving movie 'Love, Guaranteed'.
# Error retrieving movie 'Feel the Beat'.
# Error retrieving movie 'Babyteeth'.
# Error retrieving movie 'Spelling the Dream'.
# Error retrieving movie 'A Secret Love'.
# Error retrieving movie 'Love Wedding Repeat'.
# Error retrieving movie 'Almost Love'.
# Error retrieving movie 'Hope Gap'.
# Error retrieving movie 'All the Bright Places'.
# Error retrieving movie 'The Photograph'.
# Error retrieving movie 'You Go to My Head'.
# Error retrieving movie 'Ordinary Love'.
# Error retrieving movie 'To All the Boys: P.S. I Still Love You'.
# Error retrieving movie 'The Woman Who Loves Giraffes'.
# Error retrieving movie 'Queen & Slim'.
# Error retrieving movie 'Marriage Story'.
# Error retrieving movie 'Cyrano, My Love'.
# Error retrieving movie 'Pretenders'.
# Error retrieving movie 'First Love'.
# Error retrieving movie 'Loro'.
# Error retrieving movie 'Falling Inn Love'.
# Error retrieving movie 'Hot Air'.
# Error retrieving movie 'Love, Antosha'.
# Error retrieving movie 'Leto'.
# Error retrieving movie 'The Tomorrow Man'.
# Error retrieving movie 'Asako I & II'.
# Error retrieving movie 'The Sun Is Also a Star'.
# Error retrieving movie 'Shéhérazade'.
# Error retrieving movie 'Long Shot'.
# Error retrieving movie 'Clara'.
# Error retrieving movie 'Kalank'.
# Error retrieving movie 'Rafiki'.
# Error retrieving movie 'Diane'.
# Error retrieving movie 'Five Feet Apart'.
# Error retrieving movie 'Ash Is Purest White'.
# Error retrieving movie 'Gloria Bell'.
# Error retrieving movie 'Black Mother'.
# Error retrieving movie 'The Hole in the Ground'.
# Error retrieving movie 'How to Train Your Dragon: The Hidden World'.
# Error retrieving movie 'A Tuba to Cuba'.
# Error retrieving movie 'Fighting With My Family'.
# Error retrieving movie 'Sorry Angel'.
# Error retrieving movie 'Berlin, I Love You'.
# Error retrieving movie 'Untogether'.
# Error retrieving movie 'Cold War'.
# Error retrieving movie 'If Beale Street Could Talk'.
# Error retrieving movie 'Asher'.
# Error retrieving movie 'The Party’s Just Beginning'.
# Error retrieving movie 'The Great Pretender'.
# Error retrieving movie 'Sicilian Ghost Story'.
# Error retrieving movie 'The New Romantic'.
# Error retrieving movie 'Pimp'.
# Error retrieving movie 'In a Relationship'.
# Error retrieving movie 'They’ll Love Me When I’m Dead’ Documents Orson Welles’s Last Fil'.
# Error retrieving movie 'Burning,’ Love Ignites a Divided Worl'.
# Error retrieving movie 'After Everything,’ a Young Love Blooms in Crisi'.
# Error retrieving movie 'Quincy’ Captures a Lifelong Love Affair With Musi'.
# Error retrieving movie 'Love, Gilda,’ a Portrait of a Brief and Brilliant Caree'.
# Error retrieving movie 'Tea With the Dames,’ Four Legends Dish on Acting and Lov'.
# Error retrieving movie 'Bel Canto,’ Music Is the Food of Love and Rebellio'.
# Error retrieving movie 'The Citizen,’ an Immigrant Picks a Bad Time to Fall in Lov'.
# Error retrieving movie 'Love, Cecil,’ an Aesthete Ahead of His Tim'.
# Error retrieving movie 'How to Talk to Girls at Parties'.
# Error retrieving movie 'Rogers Park,’ Life and Love in a Chicago Neighborhoo'.
# Error retrieving movie 'Love & Bananas,’ Uncovering the Plight of the Asian Elephan'.
# Error retrieving movie 'Godard Mon Amour'.
# Error retrieving movie 'Submergence,’ a Love Story Sunk by Geopolitic'.
# Error retrieving movie 'Love After Love,’ an Unflinching Look at Extended Grie'.
# Error retrieving movie 'Outside In'.
# Error retrieving movie 'Love, Simon,’ a Glossy Teen Romance, the Hero Has a Secre'.
# Error retrieving movie 'Keep the Change,’ Two People With Autism Find Lov'.
# Error retrieving movie 'The Party'.
# Error retrieving movie 'The Housemaid,’ Twisted Love and Angry Ghosts in Vietna'.
# Error retrieving movie 'Forever My Girl,’ a Romance Resumes After a Long Brea'.
# Error retrieving movie 'Kangaroo: A Love-Hate Story’ Exposes a Wildlife Massacr'.
# Error retrieving movie 'Lover for a Day'.
# Error retrieving movie 'Youth,’ the People’s Dance Troupe, in Love and Wa'.
# Error retrieving movie 'Killing for Love’ Revisits a Virginia Murder Cas'.
# Error retrieving movie 'The Shape of Water’ Is Altogether Wonderfu'.
# Error retrieving movie 'Love Beats Rhymes,’ a Hip-Hop Artist Transformed by Poetr'.
# Error retrieving movie 'Cuba and the Cameraman’ Lavishes Love on a Country … and Castr'.
# Error retrieving movie 'On the Beach at Night Alone’ Zooms in on a Love Affai'.
# Error retrieving movie 'Thelma,’ a Woman in Love Can Burn Down the Worl'.
# Error retrieving movie 'Hello Again,’ a Movie Musical Ode to Love and Lust Over Decade'.
# Error retrieving movie 'It Happened in L.A.,’ All That Questing After Lov'.
# Error retrieving movie 'God’s Own Country'.
# Error retrieving movie 'The Mountain Between Us'.
# Error retrieving movie 'Dina,’ a Differently Abled Love Stor'.
# Error retrieving movie 'In Search of Fellini'.
# Error retrieving movie 'Woodpeckers,’ a Tale of Love and Agonizing Penal Confinemen'.
# Error retrieving movie 'I Do ... Until I Don’t,’ Love and Loathing in Florid'.
# Error retrieving movie 'Tales of an Immoral Couple’: Love Means Having to Grow U'.
# Error retrieving movie 'After Love’ and Regretting Every Momen'.
# Error retrieving movie 'The Last Face'.
# Error retrieving movie 'Women Who Kill,’ and May Be in Love With On'.
# Error retrieving movie 'False Confessions,’ the Play’s Not Quite the Thin'.
# Error retrieving movie 'Review: Those Movies, Himself — Bertrand Tavernier’s Tour of French Cinem'.
# Error retrieving movie 'The Big Sick,’ Comedy Is Hard, Love Harde'.
# Error retrieving movie 'Lost in Paris'.
# Error retrieving movie 'Vincent N Roxxy,’ Love Is in the Air, N So Is Fea'.
# Error retrieving movie 'Everything, Everything’ Pits Love Against Diseas'.
# Error retrieving movie 'Hounds of Love’ Is Tense and Deadly Down Unde'.
# Error retrieving movie 'Harold and Lillian’ Introduces a Hollywood Power Coupl'.
# Error retrieving movie 'The Happiest Day in the Life of Olli Maki,’ Love and Life on the Rope'.
# Error retrieving movie 'The Promise’ Finds a Love Triangle in Constantinopl'.
# Error retrieving movie 'Frantz,’ a Mysterious Frenchman and the Wounds of Wa'.
# Error retrieving movie 'The Other Half'.
# Error retrieving movie 'The Ottoman Lieutenant'.
# Error retrieving movie 'Love & Taxes'.
# Error retrieving movie 'Everybody Loves Somebody,’ a Rom-Com With Bit'.
# Error retrieving movie 'Kedi,’ Rekindling a ‘Love of Life'.

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
# Out:
# [
#     {
#         "title": "The Attachment Diaries",
#         "original_title": "El apego",
#         "budget": 0,
#         "genre": [
#             "Drama",
#             "Mystery",
#             "Thriller",
#             "Horror"
#         ],
#         "language": "es",
#         "spoken_languages": [
#             "Spanish"
#         ],
#         "homepage": "",
#         "overview": "Argentina, 1970s. A desperate young woman goes to a clinic to have a clandestine abortion. As her pregnancy is already through the fourth month, the doctor refuses. Instead, she proposes to sell the baby to one of her clients and offers to provide shelter in her house until the child is born. Their disturbed personalities will become intertwined in a strange and dangerous relationship.",
#         "popularity": 0.708,
#         "runtime": 102,
#         "revenue": 0,
#         "release_date": "2021-10-07",
#         "vote_average": 4.0,
#         "vote_count": 2,
#         "production_countries": [
#             "Argentina"
#         ]
#     },
#     {
#         "title": "You Can Live Forever",
#         "original_title": "You Can Live Forever",
#         "budget": 0,
#         "genre": [
#             "Drama",
#             "Romance"
#         ],
#         "language": "en",
#         "spoken_languages": [
#             "French",
#             "English"
#         ],
#         "homepage": "https://gooddeedentertainment.com/you-can-live-forever/",
#         "overview": "When Jaime, a gay teenager, is sent to live in a community of Jehovah's Witnesses in small-town Quebec, she falls madly in love with a devout Witness girl. The two embark on an intense affair with consequences that will reshape the rest of their lives.",
#         "popularity": 12.027,
#         "runtime": 96,
#         "revenue": 0,
#         "release_date": "2023-03-24",
#         "vote_average": 7.643,
#         "vote_count": 21,
#         "production_countries": [
#             "Canada"
#         ]
#     },
#     {
#         "title": "A Tourist's Guide to Love",
#         "original_title": "A Tourist's Guide to Love",
#         "budget": 0,
#         "genre": [
#             "Romance",
#             "Comedy",
#             "Adventure"
#         ],
#         "language": "en",
#         "spoken_languages": [
#             "English"
#         ],
#         "homepage": "https://www.netflix.com/title/81424906",
#         "overview": "After an unexpected break up, a travel executive accepts an assignment to go undercover and learn about the tourist industry in Vietnam. Along the way, she finds adventure and romance with her Vietnamese expat tour guide and they decide to hijack the tour bus in order to explore life and love off the beaten path.",
#         "popularity": 25.369,
#         "runtime": 96,
#         "revenue": 0,
#         "release_date": "2023-04-21",
#         "vote_average": 6.389,
#         "vote_count": 122,
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Other People's Children",
#         "original_title": "Les Enfants des autres",
#         "budget": 0,
#         "genre": [
#             "Drama"
#         ],
#         "language": "fr",
#         "spoken_languages": [
#             "French"
#         ],
#         "homepage": "https://www.wildbunch.biz/movie/other-peoples-children/",
#         "overview": "Rachel loves her life, her students, her friends, her ex, her guitar lessons. When she falls in love with Ali, she grows close to his 4-year-old daughter, Leila. She tucks her in, looks after her, and loves her like a mother... which she isn\u2019t. Not yet. Rachel is 40. The desire for a family of her own is growing stronger, and the clock is ticking. Is it too late?",
#         "popularity": 16.246,
#         "runtime": 104,
#         "revenue": 0,
#         "release_date": "2022-09-21",
#         "vote_average": 6.9,
#         "vote_count": 137,
#         "production_countries": [
#             "France"
#         ]
#     },
#     {
#         "title": "One True Loves",
#         "original_title": "One True Loves",
#         "budget": 0,
#         "genre": [
#             "Romance",
#             "Drama",
#             "Comedy"
#         ],
#         "language": "en",
#         "spoken_languages": [
#             "English"
#         ],
#         "homepage": "",
#         "overview": "Emma and Jesse are living the perfect life together, until Jesse disappears in a tragic helicopter crash on their first wedding anniversary. Four years later, Emma has found happiness again and is about to marry her best friend when Jesse resurfaces, turning her world upside down and leaving her torn between two great loves.",
#         "popularity": 28.872,
#         "runtime": 100,
#         "revenue": 37820,
#         "release_date": "2023-04-07",
#         "vote_average": 6.681,
#         "vote_count": 36,
#         "production_countries": [
#             "Germany",
#             "United States of America"
#         ]
#     }
# ]

# %%
# Convert the results to a DataFrame
# Out:
#                          title             original_title    budget  \
# 0       The Attachment Diaries                   El apego         0
# 1         You Can Live Forever       You Can Live Forever         0
# 2    A Tourist's Guide to Love  A Tourist's Guide to Love         0
# 3      Other People's Children     Les Enfants des autres         0
# 4               One True Loves             One True Loves         0
# ..                         ...                        ...       ...
# 150              The Last Face              The Last Face         0
# 151              Lost in Paris            Paris pieds nus         0
# 152             The Other Half             The Other Half         0
# 153     The Ottoman Lieutenant     The Ottoman Lieutenant  40000000
# 154             Rich in Love 2            Ricos de Amor 2         0
#
#                                   genre language       spoken_languages  \
# 0    [Drama, Mystery, Thriller, Horror]       es              [Spanish]
# 1                      [Drama, Romance]       en      [French, English]
# 2          [Romance, Comedy, Adventure]       en              [English]
# 3                               [Drama]       fr               [French]
# 4              [Romance, Drama, Comedy]       en              [English]
# ..                                  ...      ...                    ...
# 150                             [Drama]       en  [English, Portuguese]
# 151                            [Comedy]       fr               [French]
# 152            [Drama, Comedy, Romance]       en              [English]
# 153               [Romance, Drama, War]       en     [English, Turkish]
# 154                   [Romance, Comedy]       pt           [Portuguese]
#
#                                               homepage  \
# 0
# 1    https://gooddeedentertainment.com/you-can-live...
# 2               https://www.netflix.com/title/81424906
# 3    https://www.wildbunch.biz/movie/other-peoples-...
# 4
# ..                                                 ...
# 150
# 151
# 152
# 153  https://www.uphe.com/movies/the-ottoman-lieute...
# 154
#
#                                               overview  popularity  runtime  \
# 0    Argentina, 1970s. A desperate young woman goes...       0.708      102
# 1    When Jaime, a gay teenager, is sent to live in...      12.027       96
# 2    After an unexpected break up, a travel executi...      25.369       96
# 3    Rachel loves her life, her students, her frien...      16.246      104
# 4    Emma and Jesse are living the perfect life tog...      28.872      100
# ..                                                 ...         ...      ...
# 150  Miguel, a heroic Spanish doctor, puts himself ...       9.081      130
# 151  Fiona visits Paris for the first time to assis...       6.798       83
# 152  When English Mark surprises his American bride...       1.058       94
# 153  Lillie, a determined American woman, ventures ...      12.097      111
# 154  When the idealistic Paula resumes her work as ...      33.808       89
#
#      revenue release_date  vote_average  vote_count  \
# 0          0   2021-10-07         4.000           2
# 1          0   2023-03-24         7.643          21
# 2          0   2023-04-21         6.389         122
# 3          0   2022-09-21         6.900         137
# 4      37820   2023-04-07         6.681          36
# ..       ...          ...           ...         ...
# 150        0   2017-01-11         5.617         184
# 151        0   2017-01-14         6.051         108
# 152        0   2006-05-15         6.708          12
# 153   413844   2017-03-10         6.150         236
# 154        0   2023-06-02         6.925          60
#
#                     production_countries
# 0                            [Argentina]
# 1                               [Canada]
# 2             [United States of America]
# 3                               [France]
# 4    [Germany, United States of America]
# ..                                   ...
# 150           [United States of America]
# 151                    [Belgium, France]
# 152                     [United Kingdom]
# 153   [Turkey, United States of America]
# 154                             [Brazil]
#
# [155 rows x 15 columns]

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
# Out:
#                               title                  original_title    budget  \
# 0            The Attachment Diaries                        El apego         0
# 1              You Can Live Forever            You Can Live Forever         0
# 2                    One True Loves                  One True Loves         0
# 3    The Lost Weekend: A Love Story  The Lost Weekend: A Love Story         0
# 4                A Thousand and One              A Thousand and One         0
# ..                              ...                             ...       ...
# 120            In Search of Fellini            In Search of Fellini         0
# 121                   The Last Face                   The Last Face         0
# 122                   Lost in Paris                 Paris pieds nus         0
# 123                  The Other Half                  The Other Half         0
# 124          The Ottoman Lieutenant          The Ottoman Lieutenant  40000000
#
#                                   genre language       spoken_languages  \
# 0    [Drama, Mystery, Thriller, Horror]       es              [Spanish]
# 1                      [Drama, Romance]       en      [French, English]
# 2              [Romance, Drama, Comedy]       en              [English]
# 3                         [Documentary]       en                     []
# 4                               [Drama]       en              [English]
# ..                                  ...      ...                    ...
# 120                  [Drama, Adventure]       en              [English]
# 121                             [Drama]       en  [English, Portuguese]
# 122                            [Comedy]       fr               [French]
# 123            [Drama, Comedy, Romance]       en              [English]
# 124               [Romance, Drama, War]       en     [English, Turkish]
#
#                                               homepage  \
# 0
# 1    https://gooddeedentertainment.com/you-can-live...
# 2
# 3
# 4    https://www.focusfeatures.com/a-thousand-and-one/
# ..                                                 ...
# 120
# 121
# 122
# 123
# 124  https://www.uphe.com/movies/the-ottoman-lieute...
#
#                                               overview  popularity  runtime  \
# 0    Argentina, 1970s. A desperate young woman goes...       0.708      102
# 1    When Jaime, a gay teenager, is sent to live in...      12.027       96
# 2    Emma and Jesse are living the perfect life tog...      28.872      100
# 3    May Pang lovingly recounts her life in rock & ...       2.368       97
# 4    Struggling but unapologetically living on her ...      11.704      116
# ..                                                 ...         ...      ...
# 120  Lucy, a small-town girl from Ohio, discovers t...       4.103       93
# 121  Miguel, a heroic Spanish doctor, puts himself ...       9.081      130
# 122  Fiona visits Paris for the first time to assis...       6.798       83
# 123  When English Mark surprises his American bride...       1.058       94
# 124  Lillie, a determined American woman, ventures ...      12.097      111
#
#      ...                                      headline.main headline.kicker  \
# 0    ...        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    ...  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 2    ...     ‘One True Loves’ Review: A Romance Lost at Sea            None
# 3    ...  ‘The Lost Weekend: A Love Story’ Review: When ...            None
# 4    ...  ‘A Thousand and One’ Review: A New York Love S...   Critic’s Pick
# ..   ...                                                ...             ...
# 120  ...  Review: Love of Il Maestro Drives ‘In Search o...            None
# 121  ...  Review: Aid Workers in Love and War in Sean Pe...            None
# 122  ...  Review: Finding Love (and Slapstick) While ‘Lo...            None
# 123  ...  Review: A Combustible Pair Find Love in ‘The O...            None
# 124  ...  Review: Love as the World Wars, in ‘The Ottoma...            None
#
#      headline.content_kicker  \
# 0                       None
# 1                       None
# 2                       None
# 3                       None
# 4                       None
# ..                       ...
# 120                     None
# 121                     None
# 122                     None
# 123                     None
# 124                     None
#
#                                headline.print_headline headline.name  \
# 0                               The Attachment Diaries          None
# 1                                 You Can Live Forever          None
# 2                                       One True Loves          None
# 3                      The Lost Weekend:  A Love Story          None
# 4              An Unbending Will Meets a Shifting City          None
# ..                                                 ...           ...
# 120                               In Search of Fellini          None
# 121                                      The Last Face          None
# 122                                      Lost in Paris          None
# 123  Review: A Combustible Pair Find Love in ‘The O...          None
# 124  Review: Love as the World Wars, in ‘The Ottoma...          None
#
#     headline.seo headline.sub           byline.original  \
# 0           None         None    By Jeannette Catsoulis
# 1           None         None  By Elisabeth Vincentelli
# 2           None         None             By Brandon Yu
# 3           None         None            By Glenn Kenny
# 4           None         None         By Manohla Dargis
# ..           ...          ...                       ...
# 120         None         None        By Monica Castillo
# 121         None         None            By Glenn Kenny
# 122         None         None         By Ben Kenigsberg
# 123         None         None           By Andy Webster
# 124         None         None        By Neil Genzlinger
#
#                                          byline.person byline.organization
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 2    [{'firstname': 'Brandon', 'middlename': None, ...                None
# 3    [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 120  [{'firstname': 'Monica', 'middlename': None, '...                None
# 121  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 122  [{'firstname': 'Ben', 'middlename': None, 'las...                None
# 123  [{'firstname': 'Andy', 'middlename': None, 'la...                None
# 124  [{'firstname': 'Neil', 'middlename': None, 'la...                None
#
# [125 rows x 31 columns]

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing


# Create a list of characters to remove


# Loop through the list of columns to fix

    # Convert the column to type 'str'


    # Loop through characters to remove


# Display the fixed DataFrame
# Out:
#                             title                  original_title  budget  \
# 0          The Attachment Diaries                        El apego       0
# 1            You Can Live Forever            You Can Live Forever       0
# 2                  One True Loves                  One True Loves       0
# 3  The Lost Weekend: A Love Story  The Lost Weekend: A Love Story       0
# 4              A Thousand and One              A Thousand and One       0
#
#                               genre language spoken_languages  \
# 0  Drama, Mystery, Thriller, Horror       es          Spanish
# 1                    Drama, Romance       en  French, English
# 2            Romance, Drama, Comedy       en          English
# 3                       Documentary       en
# 4                             Drama       en          English
#
#                                             homepage  \
# 0
# 1  https://gooddeedentertainment.com/you-can-live...
# 2
# 3
# 4  https://www.focusfeatures.com/a-thousand-and-one/
#
#                                             overview  popularity  runtime  \
# 0  Argentina, 1970s. A desperate young woman goes...       0.708      102
# 1  When Jaime, a gay teenager, is sent to live in...      12.027       96
# 2  Emma and Jesse are living the perfect life tog...      28.872      100
# 3  May Pang lovingly recounts her life in rock & ...       2.368       97
# 4  Struggling but unapologetically living on her ...      11.704      116
#
#    ...                                      headline.main headline.kicker  \
# 0  ...        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  ...  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 2  ...     ‘One True Loves’ Review: A Romance Lost at Sea            None
# 3  ...  ‘The Lost Weekend: A Love Story’ Review: When ...            None
# 4  ...  ‘A Thousand and One’ Review: A New York Love S...   Critic’s Pick
#
#    headline.content_kicker                  headline.print_headline  \
# 0                     None                   The Attachment Diaries
# 1                     None                     You Can Live Forever
# 2                     None                           One True Loves
# 3                     None          The Lost Weekend:  A Love Story
# 4                     None  An Unbending Will Meets a Shifting City
#
#   headline.name headline.seo headline.sub           byline.original  \
# 0          None         None         None    By Jeannette Catsoulis
# 1          None         None         None  By Elisabeth Vincentelli
# 2          None         None         None             By Brandon Yu
# 3          None         None         None            By Glenn Kenny
# 4          None         None         None         By Manohla Dargis
#
#                                        byline.person byline.organization
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 2  [{'firstname': 'Brandon', 'middlename': None, ...                None
# 3  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 4  [{'firstname': 'Manohla', 'middlename': None, ...                None
#
# [5 rows x 31 columns]

# %%
# Drop "byline.person" column

# %%
# Delete duplicate rows and reset index
# Out:
#                             title                  original_title  budget  \
# 0          The Attachment Diaries                        El apego       0
# 1            You Can Live Forever            You Can Live Forever       0
# 2                  One True Loves                  One True Loves       0
# 3  The Lost Weekend: A Love Story  The Lost Weekend: A Love Story       0
# 4              A Thousand and One              A Thousand and One       0
#
#                               genre language spoken_languages  \
# 0  Drama, Mystery, Thriller, Horror       es          Spanish
# 1                    Drama, Romance       en  French, English
# 2            Romance, Drama, Comedy       en          English
# 3                       Documentary       en
# 4                             Drama       en          English
#
#                                             homepage  \
# 0
# 1  https://gooddeedentertainment.com/you-can-live...
# 2
# 3
# 4  https://www.focusfeatures.com/a-thousand-and-one/
#
#                                             overview  popularity  runtime  \
# 0  Argentina, 1970s. A desperate young woman goes...       0.708      102
# 1  When Jaime, a gay teenager, is sent to live in...      12.027       96
# 2  Emma and Jesse are living the perfect life tog...      28.872      100
# 3  May Pang lovingly recounts her life in rock & ...       2.368       97
# 4  Struggling but unapologetically living on her ...      11.704      116
#
#    ...  word_count                                      headline.main  \
# 0  ...         295        ‘The Attachment Diaries’ Review: Love, Sick
# 1  ...         294  ‘You Can Live Forever’ Review: Do You Love Me ...
# 2  ...         320     ‘One True Loves’ Review: A Romance Lost at Sea
# 3  ...         327  ‘The Lost Weekend: A Love Story’ Review: When ...
# 4  ...         971  ‘A Thousand and One’ Review: A New York Love S...
#
#    headline.kicker  headline.content_kicker  \
# 0             None                     None
# 1             None                     None
# 2             None                     None
# 3             None                     None
# 4    Critic’s Pick                     None
#
#                    headline.print_headline headline.name headline.seo  \
# 0                   The Attachment Diaries          None         None
# 1                     You Can Live Forever          None         None
# 2                           One True Loves          None         None
# 3          The Lost Weekend:  A Love Story          None         None
# 4  An Unbending Will Meets a Shifting City          None         None
#
#   headline.sub           byline.original byline.organization
# 0         None    By Jeannette Catsoulis                None
# 1         None  By Elisabeth Vincentelli                None
# 2         None             By Brandon Yu                None
# 3         None            By Glenn Kenny                None
# 4         None         By Manohla Dargis                None
#
# [5 rows x 30 columns]

# %%
# Export data to CSV without the index
